# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score

# %%
df = pd.read_csv(r'C:\Users\richi\OneDrive\Desktop\customer_purchase_data.csv')
df
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
df.shape
# Out:
# (1500, 9)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x='PurchaseStatus')
plt.title('Distribution of PurchaseStatus')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x='Gender')
plt.title('Distribution of Gender')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    757
# 0    743
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['AnnualIncome'],kde = True)
plt.title('Distribution of AnnualIncomer')
plt.show()
# Out:
# C:\Users\richi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['NumberOfPurchases'],kde = True)
plt.title('Distribution of NumberOfPurchases')
plt.show()
# Out:
# C:\Users\richi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = df, x = 'ProductCategory')
plt.title('Distribution of ProductCategory')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['TimeSpentOnWebsite'],kde = True)
plt.title('Distribution of TimeSpentOnWebsite')
plt.show()
# Out:
# C:\Users\richi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = df, x = 'LoyaltyProgram')
plt.title('Distribution of LoyaltyProgram')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(data = df, x = 'DiscountsAvailed')
plt.title('Distribution of DiscountsAvailed')
plt.show()

# %%
df.corr()
# Out:
#                          Age    Gender  AnnualIncome  NumberOfPurchases  \
# Age                 1.000000  0.022055      0.016438          -0.038778
# Gender              0.022055  1.000000      0.010054           0.001373
# AnnualIncome        0.016438  0.010054      1.000000           0.000276
# NumberOfPurchases  -0.038778  0.001373      0.000276           1.000000
# ProductCategory    -0.020767 -0.028572      0.032163           0.006270
# TimeSpentOnWebsite  0.032309  0.012814     -0.001505           0.024644
# LoyaltyProgram     -0.005980  0.033302     -0.045296           0.055358
# DiscountsAvailed    0.004009 -0.056624      0.016393           0.029581
# PurchaseStatus     -0.255747  0.002627      0.188214           0.222691
#
#                     ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  \
# Age                       -0.020767            0.032309       -0.005980
# Gender                    -0.028572            0.012814        0.033302
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot = True, cmap='coolwarm')
plt.title('correlation heatmap')
plt.show()

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=25)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred1 = lr.predict(X_test)

# %%
accuracy_lr = accuracy_score(y_test, y_pred1)
precision_lr = precision_score(y_test, y_pred1)
recall_lr = recall_score(y_test, y_pred1)
f1_lr = f1_score(y_test, y_pred1)
cm_lr = confusion_matrix(y_test, y_pred1)

# %%
print(f'Logistic Regression:\n Accuracy: {accuracy_lr}\n Precision: {precision_lr}\n Recall: {recall_lr}\n F1 Score: {f1_lr}')
print(cm_lr)
# Out:
# Logistic Regression:
#  Accuracy: 0.82
#  Precision: 0.7688442211055276
#  Recall: 0.8138297872340425
#  F1 Score: 0.7906976744186046
# [[216  46]
#  [ 35 153]]

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train,y_train)
y_pred2 = dtc.predict(X_test)

# %%
accuracy_dtc = accuracy_score(y_test, y_pred2)
precision_dtc = precision_score(y_test, y_pred2)
recall_dtc = recall_score(y_test, y_pred2)
f1_dtc = f1_score(y_test, y_pred2)
cm_dtc = confusion_matrix(y_test, y_pred2)

# %%
print(f'DecisionTreeClassifier:\n Accuracy: {accuracy_dtc}\n Precision: {precision_dtc}\n Recall: {recall_dtc}\n F1 Score: {f1_dtc}')
print(cm_dtc)
# Out:
# DecisionTreeClassifier:
#  Accuracy: 0.8622222222222222
#  Precision: 0.8247422680412371
#  Recall: 0.851063829787234
#  F1 Score: 0.8376963350785339
# [[228  34]
#  [ 28 160]]

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred3 = rfc.predict(X_test)

# %%
accuracy_rfc = accuracy_score(y_test, y_pred3)
precision_rfc = precision_score(y_test, y_pred3)
recall_rfc = recall_score(y_test, y_pred3)
f1_rfc = f1_score(y_test, y_pred3)
cm_rfc = confusion_matrix(y_test, y_pred3)

# %%
print(f'RandomForestClassifier:\n Accuracy: {accuracy_rfc}\n Precision: {precision_rfc}\n Recall: {recall_rfc}\n F1 Score: {f1_rfc}')
print(cm_rfc)
# Out:
# RandomForestClassifier:
#  Accuracy: 0.92
#  Precision: 0.9269662921348315
#  Recall: 0.8776595744680851
#  F1 Score: 0.901639344262295
# [[249  13]
#  [ 23 165]]

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC(random_state=25)
svc.fit(X_train,y_train)
y_pred4 = svc.predict(X_test)

# %%
accuracy_svc = accuracy_score(y_test, y_pred4)
precision_svc = precision_score(y_test, y_pred4)
recall_svc = recall_score(y_test, y_pred4)
f1_svc = f1_score(y_test, y_pred4)
cm_svc = confusion_matrix(y_test, y_pred4)

# %%
print(f'SVC:\n Accuracy: {accuracy_svc}\n Precision: {precision_svc}\n Recall: {recall_svc}\n F1 Score: {f1_svc}')
print(cm_svc)
# Out:
# SVC:
#  Accuracy: 0.86
#  Precision: 0.8306878306878307
#  Recall: 0.8351063829787234
#  F1 Score: 0.8328912466843501
# [[230  32]
#  [ 31 157]]

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred5 = nb.predict(X_test)

# %%
accuracy_nb = accuracy_score(y_test, y_pred5)
precision_nb = precision_score(y_test, y_pred5)
recall_nb = recall_score(y_test, y_pred5)
f1_nb = f1_score(y_test, y_pred5)
cm_nb = confusion_matrix(y_test, y_pred5)

# %%
print(f'NB:\n Accuracy: {accuracy_nb}\n Precision: {precision_nb}\n Recall: {recall_nb}\n F1 Score: {f1_nb}')
print(cm_nb)
# Out:
# NB:
#  Accuracy: 0.8444444444444444
#  Precision: 0.8430232558139535
#  Recall: 0.7712765957446809
#  F1 Score: 0.8055555555555556
# [[235  27]
#  [ 43 145]]

# %% [markdown]
# # if we check accuracy then the Random forest classifier is the best model with a precision of 92.89% recall of 90.4% and f1_score of 91.64%
